# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
df=pd.read_csv("gold_data/XAU_1month_data_2004_to_2024-09-20.csv")
df=df.dropna()
df=df.drop(['Date','Time','High','Low','Volume'],axis=1)
df.head()
# Out:
#     Open  Close
# 0  384.0  393.3
# 1  391.6  390.5
# 2  390.3  409.3
# 3  409.6  417.8
# 4  417.8  428.1

# %%
plt.title('open price')
sns.distplot(df['Open'])
plt.show()
# Out:
# /var/folders/gl/xb73xpdd7vzdgc_y_d1b466m0000gn/T/ipykernel_42966/2627903388.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Open'])

# %%
plt.scatter(df['Open'],df['Close'],color='lightcoral')
plt.title('Open vs Close')
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.show()

# %%
X = df.iloc[:, :1]  # independent
y = df.iloc[:, 1:]  # dependent

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_test=regressor.predict(X_test)
y_pred_train=regressor.predict(X_train)

# %%
plt.scatter(X_train,y_train,color='lightcoral')
plt.plot(X_train,y_pred_train,color='firebrick')
plt.title('Close vs Open')
plt.xlabel('Close price')
plt.ylabel('Open Price')
plt.show()
